# %% [markdown]
# # Data engineering capstone project
#
# Notebook to explore, select and clean data before creating the DB and start with the ETL process

# %% [markdown]
# ###  First data frame
# SAS data

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["PATH"] = "/opt/conda/bin:/opt/spark-2.4.3-bin-hadoop2.7/bin:/opt/conda/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/lib/jvm/java-8-openjdk-amd64/bin"
os.environ["SPARK_HOME"] = "/opt/spark-2.4.3-bin-hadoop2.7"
os.environ["HADOOP_HOME"] = "/opt/spark-2.4.3-bin-hadoop2.7"
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
#df_spark =spark.read.load('./sas_data')
print("Completed, ran successfully")
# Out:
# Completed, ran successfully

# %%
import pandas as pd
pd.set_option('max_columns', None)

# %%
from pyspark.sql.functions import isnan, when, count, col

# %%
print((df_spark.count(), len(df_spark.columns)))
# Out:
# (3096313, 28)

# %%
df_spark.printSchema()
# Out:
# root
#  |-- cicid: double (nullable = true)
#  |-- i94yr: double (nullable = true)
#  |-- i94mon: double (nullable = true)
#  |-- i94cit: double (nullable = true)
#  |-- i94res: double (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: double (nullable = true)
#  |-- i94mode: double (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: double (nullable = true)
#  |-- i94bir: double (nullable = true)
#  |-- i94visa: double (nullable = true)
#  |-- count: double (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- visapost: string (nullable = true)
#  |-- occup: string (nullable = true)
#  |-- entdepa: string (nullable = true)
#  |-- entdepd: string (nullable = true)
#  |-- entdepu: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: double (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- insnum: string (nullable = true)
# ...

# %%
df_spark.limit(10).toPandas()
# Out:
#        cicid   i94yr  i94mon  i94cit  i94res i94port  arrdate  i94mode  \
# 0  5748517.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 1  5748518.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 2  5748519.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 3  5748520.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 4  5748521.0  2016.0     4.0   245.0   438.0     LOS  20574.0      1.0
# 5  5748522.0  2016.0     4.0   245.0   464.0     HHW  20574.0      1.0
# 6  5748523.0  2016.0     4.0   245.0   464.0     HHW  20574.0      1.0
# 7  5748524.0  2016.0     4.0   245.0   464.0     HHW  20574.0      1.0
# 8  5748525.0  2016.0     4.0   245.0   464.0     HOU  20574.0      1.0
# 9  5748526.0  2016.0     4.0   245.0   464.0     LOS  20574.0      1.0
#
#   i94addr  depdate  i94bir  i94visa  count  dtadfile visapost occup entdepa  \
# 0      CA  20582.0    40.0      1.0    1.0  20160430      SYD  None       G
# ...

# %%
df_spark.select([count(when(col(c).isNull(), c)).alias(c) for c in df_spark.columns]).toPandas()
# Out:
#    cicid  i94yr  i94mon  i94cit  i94res  i94port  arrdate  i94mode  i94addr  \
# 0      0      0       0       0       0        0        0      239   152592
#
#    depdate  i94bir  i94visa  count  dtadfile  visapost    occup  entdepa  \
# 0   142457     802        0      0         1   1881250  3088187      238
#
#    entdepd  entdepu  matflag  biryear  dtaddto  gender   insnum  airline  \
# 0   138429  3095921   138429      802      477  414269  2982605    83627
#
#    admnum  fltno  visatype
# 0       0  19549         0

# %%
"""
Getting rid of columns with the most 'Null' data > 50%
    * visapost
    * occup
    * entdepu
    * insnum
"""

columns_to_drop = ['visapost', 'occup', 'entdepu', 'insnum']
df_spark = df_spark.drop(*columns_to_drop)

# %%
"""
Getting rid of columns with meaninfull data
    * entdepa
    * entdepd
    * entdepd
    * count 
    * admnum
"""

columns_to_drop = ['entdepa', 'entdepd', 'entdepd', 'count', 'adnum']
df_spark = df_spark.drop(*columns_to_drop)

# %%
df_spark.printSchema()
# Out:
# root
#  |-- cicid: double (nullable = true)
#  |-- i94yr: double (nullable = true)
#  |-- i94mon: double (nullable = true)
#  |-- i94cit: double (nullable = true)
#  |-- i94res: double (nullable = true)
#  |-- i94port: string (nullable = true)
#  |-- arrdate: double (nullable = true)
#  |-- i94mode: double (nullable = true)
#  |-- i94addr: string (nullable = true)
#  |-- depdate: double (nullable = true)
#  |-- i94bir: double (nullable = true)
#  |-- i94visa: double (nullable = true)
#  |-- dtadfile: string (nullable = true)
#  |-- matflag: string (nullable = true)
#  |-- biryear: double (nullable = true)
#  |-- dtaddto: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- airline: string (nullable = true)
#  |-- admnum: double (nullable = true)
#  |-- fltno: string (nullable = true)
#  |-- visatype: string (nullable = true)

# %%
# save data as csv

# %% [markdown]
# ## Working on the second dataframe
#
# Airport data

# %%
air_path = 'airport-codes_csv.csv'
air_sp_df = spark.read.option("header",True).csv(air_path)
air_sp_df.printSchema()
# Out:
# root
#  |-- ident: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- elevation_ft: string (nullable = true)
#  |-- continent: string (nullable = true)
#  |-- iso_country: string (nullable = true)
#  |-- iso_region: string (nullable = true)
#  |-- municipality: string (nullable = true)
#  |-- gps_code: string (nullable = true)
#  |-- iata_code: string (nullable = true)
#  |-- local_code: string (nullable = true)
#  |-- coordinates: string (nullable = true)

# %%
print((air_sp_df.count(), len(air_sp_df.columns)))
# Out:
# (55075, 12)

# %%
air_sp_df.limit(10).toPandas()
# Out:
#   ident           type                                name elevation_ft  \
# 0   00A       heliport                   Total Rf Heliport           11
# 1  00AA  small_airport                Aero B Ranch Airport         3435
# 2  00AK  small_airport                        Lowell Field          450
# 3  00AL  small_airport                        Epps Airpark          820
# 4  00AR         closed  Newport Hospital & Clinic Heliport          237
# 5  00AS  small_airport                      Fulton Airport         1100
# 6  00AZ  small_airport                      Cordes Airport         3810
# 7  00CA  small_airport             Goldstone /Gts/ Airport         3038
# 8  00CL  small_airport                 Williams Ag Airport           87
# 9  00CN       heliport     Kitchen Creek Helibase Heliport         3350
#
#   continent iso_country iso_region  municipality gps_code iata_code  \
# 0        NA          US      US-PA      Bensalem      00A      None
# ...

# %%
air_sp_df.select([count(when(col(c).isNull(), c)).alias(c) for c in air_sp_df.columns]).toPandas()
# Out:
#    ident  type  name  elevation_ft  continent  iso_country  iso_region  \
# 0      0     0     0          7006          0            0           0
#
#    municipality  gps_code  iata_code  local_code  coordinates
# 0          5676     14045      45886       26389            0

# %%
"""To define if we can get rid of 
    * gps_code
    * iata_code
    * local_code
    * iso_country
because of the ammount of nulls in those columns and are kind of technical terms
however we have the coordinates extract data"""

columns_to_drop = ['gps_code', 'iata_code', 'local_code', 'iso_country']
air_sp_df= air_sp_df.drop(*columns_to_drop)

# %%
# !pip install geopy
# Out:
# ...
#     100% |████████████████████████████████| 112kB 4.4MB/s ta 0:00:01
# ...

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")

def city_state_country(coord):
    
    try:
        coord = ', '.join(str(coord.tolist()[0]).split(', ')[::-1])
        location = geolocator.reverse(str(coord))
        address = location.raw["address"]
        state = address.get('state', '')
        country = address.get('country', '')
        return [state, country]

    except ValueError:
        return(0)

temp_locations = (air_sp_df.select("coordinates").toPandas()
                   .apply(lambda row: city_state_country(row),
                          axis=1)
                 )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-db2b62019c3d> in <module>()
#      17 temp_locations = (air_sp_df.select("coordinates").toPandas()
#      18                    .apply(lambda row: city_state_country(row),
# ---> 19                           axis=1)
#      20                  )
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, result_type, args, **kwds)
#    6012                          args=args,
#    6013                          kwds=kwds)
# -> 6014         return op.get_result()
#    6015
#    6016     def applymap(self, func):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/apply.py in get_result(self)
#     140             return self.apply_raw()
#     141
# --> 142         return self.apply_standard()
#     143
#     144     def apply_empty_result(self):
#
# ...

# %%
air_df_state = spark.createDataFrame(pandasDF)(pd.DataFrame(temp_locations.apply(lambda x: x[0])))
air_df_country = spark.createDataFrame(pandasDF)(pd.DataFrame(temp_locations.apply(lambda x: x[1])))
air_sp_df = air_sp_df.withColumn("state", air_df_state)
air_sp_df = air_sp_df.withColumn("country", air_df_country)
